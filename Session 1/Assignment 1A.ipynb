# %% [markdown]
# <a href="https://colab.research.google.com/github/nrajmalwar/Project/blob/master/Session%201/Assignment%201A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Nishad Rajmalwar, Batch: F6, Email ID: nrajmalwar@gmail.com

# %% [markdown]
# # Assignment 1A #
#
# In this assignment, we will manually provide the values of 3x3 kernel in order to see how it functions. The kernels are designed to extract specific features from the image.

# %%
# import the necessary packages
import numpy as np
from urllib.request import urlopen
import cv2
from matplotlib import pyplot as plt

# METHOD #1: OpenCV, NumPy, and urllib
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
image = url_to_image("https://fontsarena-cd5e.kxcdn.com/wp-content/uploads/2019/04/helvetica-now-font-400x364.png")

# %% [markdown]
# First, let's have a look at our image:

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F489CA35B70>

# %%
edges = cv2.Canny(image,100,200)

# %% [markdown]
# If we just look at the edges in the image, we will get the following image:

# %%
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=400x364 at 0x7F4893E67160>

# %% [markdown]
# Now, we show kernels and the corresponding image for the following feature extraction:

# %% [markdown]
# ## 1. Vertical Edge Detector ##
#
# A vertical edge is detected when there is a sudden change in pixel intensity along the x-direction.
#
# ![picture alt](https://github.com/nrajmalwar/Project-1/blob/master/Images/Vertical_Edge.png?raw=true)

# %%
# Vertical edge detector

kernel = np.float32([[-1,0,1],[-1,0,1],[-1,0,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F4893E6A860>

# %% [markdown]
# ## 2. Horizontal Edge Detector ##
#
# A horizontal edge is detected when there is a sudden change in pixel intensity along the y-direction.
#
# ![picture alt](https://github.com/nrajmalwar/Project-1/blob/master/Images/Horizontal_Edges.png?raw=true)

# %%
# Horizontal edge detector

kernel = np.float32([[-1,-2,-1],[0,0,0],[1,2,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F4893E6A978>

# %% [markdown]
# ## 3. 45 Degree Angle Detector ##
#
# A 45 degree angle is detected when there is a sudden change in pixel intensity along the 45 degree or 135 degree angles.
#
# ![picture alt](https://github.com/nrajmalwar/Project-1/blob/master/Images/45_Degrees.png?raw=true)

# %%
# 45 Degree Angle Detector

kernel = np.float32([[2,0,-2],[0,0,0],[-2,0,2]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F4893E6A860>

# %% [markdown]
# ## 4. Blur ##
#
# A blur kernel changes a single pixel value to the average of its neighbouring pixel values.
#
# ![alt text](https://github.com/nrajmalwar/Project-1/blob/master/Images/Blur.png?raw=true)

# %%
# Blur Kernel

kernel = (1/9)*np.float32([[1,1,1],[1,1,1],[1,1,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F4893E6AA58>

# %% [markdown]
# ## 5. Sharpen ##
#
# The sharpen kernel emphasizes difference in adjacent pixel values
#
# ![picture alt](https://github.com/nrajmalwar/Project-1/blob/master/Images/Sharpen.png?raw=true)

# %%
# Sharpen Kernel

kernel = np.float32([[0,-1,0],[-1,5,-1],[0,-1,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F4893E6AB70>

# %% [markdown]
# ## 6. Identity ##
#
# The identity kernel does not modify any pixel values and gives the original image as output.
#
# ![picture alt](https://github.com/nrajmalwar/Project-1/blob/master/Images/Identity.png?raw=true)

# %%
# Identity Function

kernel = np.float32([[0,0,0],[0,1,0],[0,0,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7F4893E6A940>
